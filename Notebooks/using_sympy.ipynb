# %%
import sys
import os

# Add project root and parent directory to path
project_root = os.path.abspath("..")
parent_dir = os.path.abspath(os.path.join("..", ".."))

if project_root not in sys.path:
    sys.path.append(project_root)
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# %%
from sbmlParser.parser import ParseSBMLFile

# %%
sbml_file = "../data/euromix.sbml"  # Or your SBML file
model_data = ParseSBMLFile(sbml_file)

# %%
import sympy as sp
from sbml_rust_generator.models import SbmlModel

# %%
# Parse model into structured format
model = SbmlModel.from_dict(model_data)

# %%
species_list = list(model.species.keys())
species_map = {s_id: i for i, s_id in enumerate(species_list)}

# %%
# Create symbol dictionaries
sym_species = {s: sp.Symbol(s) for s in species_list}
sym_params = {p: sp.Symbol(p) for p in model.parameters.keys()}
sym_compartments = {c: sp.Symbol(c) for c in model.compartments.keys()}

# %%
# Combine all symbols for parser
all_syms = {**sym_species, **sym_params, **sym_compartments}

# %%
from sbml_rust_generator import SbmlExpressionParser, OdeSystemBuilder

parser = SbmlExpressionParser(all_syms, model_data.get("functions", {}))

# %%
# Build ODE system
ode_builder = OdeSystemBuilder(species_map, parser)
ode_system = ode_builder.build_ode_system(model_data["reactions"])
# Out:
# Parsing reactions...

# %%
ode_system
# Out:
# [1.0*FFat*QFat/(Fat*PCFat) - 1.0*FFat*QArt/Art,
#  1.0*FRich*QRich/(PCRich*Rich) - 1.0*FRich*QArt/Art,
#  1.0*FPoor*QPoor/(PCPoor*Poor) - 1.0*FPoor*QArt/Art,
#  1.0*FLiver*QLiver/(Liver*PCLiver) - 1.0*QGut*kGut + 1.0*fub*Piecewise((Liver*Vmax*Piecewise((QLiver/Liver, Liver > 0), (0, True))/(Km*PCLiver + Piecewise((QLiver/Liver, Liver > 0), (0, True))), Michaelis > 0.5), (CLH*Piecewise((QLiver/Liver, Liver > 0), (0, True))/PCLiver, True)) - 1.0*FLiver*QArt/Art,
#  -1.0*fub*Piecewise((Liver*Vmax*Piecewise((QLiver/Liver, Liver > 0), (0, True))/(Km*PCLiver + Piecewise((QLiver/Liver, Liver > 0), (0, True))), Michaelis > 0.5), (CLH*Piecewise((QLiver/Liver, Liver > 0), (0, True))/PCLiver, True)),
#  1.0*QGut*kGut,
#  1.0*FSkin_u*Piecewise((QSkin_u/Skin_u, Skin_u > 0), (0, True))/PCSkin - 1.0*f_su*Piecewise((QSkin_sc_u/Skin_sc_u, Skin_sc_u > 0), (0, True)) + 1.0*f_su*Piecewise((QSkin_u/Skin_u, Skin_u > 0), (0, True))/PCSkin_sc - 1.0*FSkin_u*QArt/Art,
#  1.0*FSkin_e*Piecewise((QSkin_e/Skin_e, Skin_e > 0), (0, True))/PCSkin - 1.0*f_se*Piecewise((QSkin_sc_e/Skin_sc_e, Skin_sc_e > 0), (0, True)) + 1.0*f_se*Piecewise((QSkin_e/Skin_e, Skin_e > 0), (0, True))/PCSkin_sc - 1.0*FSkin_e*QArt/Art,
#  1.0*f_su*Piecewise((QSkin_sc_u/Skin_sc_u, Skin_sc_u > 0), (0, True)) - 1.0*f_su*Piecewise((QSkin_u/Skin_u, Skin_u > 0), (0, True))/PCSkin_sc,
#  1.0*f_se*Piecewise((QSkin_sc_e/Skin_sc_e, Skin_sc_e > 0), (0, True)) - 1.0*f_se*Piecewise((QSkin_e/Skin_e, Skin_e > 0), (0, True))/PCSkin_sc,
#  -1.0*FBlood*QVen/Ven + 1.0*FFat*QArt/Art + 1.0*FLiver*QArt/Art + 1.0*FPoor*QArt/Art + 1.0*FRich*QArt/Art + 1.0*FSkin_e*QArt/Art + 1.0*FSkin_u*QArt/Art + 1.0*Falv*QArt/(Art*PCAir) + 1.0*Ke*QArt*fub/Art - 1.0*FBlood*QAir/Air,
#  1.0*FBlood*QVen/Ven - 1.0*FFat*QFat/(Fat*PCFat) - 1.0*FLiver*QLiver/(Liver*PCLiver) - 1.0*FPoor*QPoor/(PCPoor*Poor) - 1.0*FRich*QRich/(PCRich*Rich) - 1.0*FSkin_e*Piecewise((QSkin_e/Skin_e, Skin_e > 0), (0, True))/PCSkin - 1.0*FSkin_u*Piecewise((QSkin_u/Skin_u, Skin_u > 0), (0, True))/PCSkin,
#  -1.0*Ke*QArt*fub/Art,
#  -1.0*Falv*QArt/(Art*PCAir) + 1.0*FBlood*QAir/Air]

# %%
print(f"Built {len(ode_system)} ODEs")
print("\nFirst ODE:")
print(ode_system[0])
# Out:
# Built 14 ODEs
#
# First ODE:
# 1.0*FFat*QFat/(Fat*PCFat) - 1.0*FFat*QArt/Art

# %%
# Cell 10: Compute sparse Jacobian
from sbml_rust_generator import JacobianBuilder

# Create Jacobian builder
jac_builder = JacobianBuilder(sym_species, species_list)

# %%
# Compute sparse Jacobian (only non-zero elements)
jac_elements, jac_indices = jac_builder.compute_sparse_jacobian(ode_system)
# Out:
# Computing Jacobian (sparse)...
# Jacobian sparsity: 34/196 non-zero

# %%
from sbml_rust_generator import SymbolicOptimizer

optimizer = SymbolicOptimizer(optimization_level=2)

# %%
# Optimize ODE and Jacobian together
replacements, reduced_ode, reduced_jac = optimizer.optimize_combined(ode_system, jac_elements)
# Out:
# Optimizing ODE and Jacobian together...
# Optimizing expressions with CSE...
# DEBUG: Processing 74 CSE replacements for safe divisions...
# DEBUG: Symbol x15 can be zero
# DEBUG: x16 expression tree: 1/(Km*PCLiver + x15)
# DEBUG: x16 expression type: <class 'sympy.core.power.Pow'>
# DEBUG: x16 expression args: (Km*PCLiver + x15, -1)
# DEBUG: x16 Pow#1: base=Km*PCLiver + x15, base_type=Add, exp=-1
# DEBUG: x16 Pow#1: is base a Symbol? False
# DEBUG: Found unsafe division in x16: Km*PCLiver + x15^-1 (contains zero symbol)
# DEBUG: Rewriting x16 expression to make safe
# DEBUG: Symbol x29 can be zero
# DEBUG: Symbol x32 can be zero
# DEBUG: Symbol x41 can be zero
# DEBUG: Symbol x44 can be zero
# DEBUG: Symbol x61 can be zero
# DEBUG: Symbol x67 can be zero
# DEBUG: Symbol x68 can be zero
# DEBUG: Symbol x70 can be zero
# DEBUG: Symbol x71 can be zero
# DEBUG: Total zero-valued symbols found: 10
# DEBUG: Zero symbols: {x15, x67, x61, x71, x41, x68, x44, x70, x32, x29}
# CSE extracted 74 common subexpressions

# %%
from sbml_rust_generator.codegen import RustBlockGenerator

code_gen = RustBlockGenerator()

# Generate species extraction code
species_extract = code_gen.generate_species_extraction(species_map)

# Generate temporary variables (CSE)
temp_vars = code_gen.generate_temp_vars(replacements)

# Generate ODE derivatives
derivatives = code_gen.generate_derivatives(reduced_ode)

# Generate Jacobian-vector product
jacobian_code = code_gen.generate_jacobian(reduced_jac, jac_indices)

# Generate result vectors initialization
result_vectors = code_gen.generate_result_vectors_init(species_list)

# Generate result pushes
result_pushes = code_gen.generate_result_pushes(species_list)

# Generate HashMap inserts
hashmap_inserts = code_gen.generate_hashmap_inserts(species_list)

# %%
from sbml_rust_generator.codegen import RustTemplateManager

# Prepare code blocks dictionary
code_blocks = {
    "n_species": len(species_list),
    "species_extract": species_extract,
    "temp_vars": temp_vars,
    "rhs_block": derivatives,
    "jac_block": jacobian_code,
    "result_vectors_init": result_vectors,
    "loop_pushes": result_pushes,
    "initial_pushes": result_pushes,
    "hashmap_inserts": hashmap_inserts,
    "gut_idx": species_map.get("QGut", 0),  # Adjust for your model
}

# Assemble Rust file
template_manager = RustTemplateManager()
rust_code = template_manager.assemble_rust_file("my_model", code_blocks)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 19
#      17 # Assemble Rust file
#      18 template_manager = RustTemplateManager()
# ---> 19 rust_code = template_manager.assemble_rust_file("my_model", code_blocks)
#
# File d:\Rust\sbml_rust_generator\codegen\template_manager.py:84, in RustTemplateManager.assemble_rust_file(self, model_name, components)
#      44     def assemble_rust_file(
#      45         self,
#      46         model_name: str,
#      47         components: Dict[str, str]
#      48     ) -> str:
#      49         """Assemble complete Rust file from components
#      50
#      51         Args:
#    (...)     69             Complete Rust source code
#      70         """
#      71         template = f'''// Generated WASM-compatible Rust code from SBML model: {model_name}
#      72 // Uses SymPy CSE for optimized derivatives and Jacobian
#      73
#      74 use diffsol::{{OdeBuilder, OdeSolverMethod, OdeSolverStopReason, Vector}};
#      75 use wasm_bindgen::prelude::*;
#      76 use serde::{{Deserialize, Serialize}};
#      77 use std::collections::HashMap;
#      78
#      79 type M = diffsol::NalgebraMat<f64>;
#      80 type LS = diffsol::NalgebraLU<f64>;
#      81
#      82 #[derive(Serialize, Deserialize)]
#      83 pub struct SimulationResult {{
# ---> 84 {components["species_fields"]}
#      85     pub time: Vec<f64>,
#      86 }}
#      87
#      88 #[derive(Serialize, Deserialize)]
#      89 pub struct SimulationParams {{
#      90 {components["param_fields"]}
#      91     pub doses: Vec<(f64, f64)>,
#      92     pub final_time: Option<f64>,
#      93 }}
#      94
#      95 #[wasm_bindgen]
#      96 extern "C" {{
#      97     #[wasm_bindgen(js_namespace = console)]
#      98     fn log(s: &str);
#      99 }}
#     100
#     101 macro_rules! console_log {{
#     102     ($($t:tt)*) => (log(&format_args!($($t)*).to_string()))
#     103 }}
#     104
#     105 #[wasm_bindgen]
#     106 pub fn run_simulation(params: &str) -> String {{
#     107     console_log!("Starting simulation...");
#     108
#     109     let sim_params: SimulationParams = match serde_json::from_str(params) {{
#     110         Ok(p) => p,
#     111         Err(e) => {{
#     112             console_log!("Error parsing params: {{}}", e);
#     113             return serde_json::to_string(&SimulationResult {{
#     114                 species: HashMap::new(),
#     115                 time: vec![],
#     116             }}).unwrap();
#     117         }}
#     118     }};
#     119
#     120 {components["param_extract"]}
#     121     let doses = sim_params.doses;
#     122
#     123     // RHS Closure
#     124     let rhs = |y: &diffsol::NalgebraVec<f64>, _p: &diffsol::NalgebraVec<f64>, _t: f64, dy: &mut diffsol::NalgebraVec<f64>| {{
#     125         // Map species names to y indices
#     126 {components["species_extract"]}
#     127
#     128         // Temporary variables (CSE)
#     129 {components["temp_vars"]}
#     130
#     131         // Derivatives
#     132 {components["rhs_block"]}
#     133     }};
#     134
#     135     // Jacobian Closure (Matrix-Vector Product)
#     136     let jac = |y: &diffsol::NalgebraVec<f64>, _p: &diffsol::NalgebraVec<f64>, _t: f64, v: &diffsol::NalgebraVec<f64>, jv: &mut diffsol::NalgebraVec<f64>| {{
#     137         for i in 0..jv.len() {{ jv[i] = 0.0; }}
#     138
#     139         // Map species names to y indices
#     140 {components["species_extract"]}
#     141
#     142         // Temporary variables (CSE)
#     143 {components["temp_vars"]}
#     144
#     145         // Jacobian-Vector Product
#     146 {components["jac_block"]}
#     147     }};
#     148
#     149     let init = |_y0: &diffsol::NalgebraVec<f64>, _t: f64, y: &mut diffsol::NalgebraVec<f64>| {{
#     150         for i in 0..{components["n_species"]} {{ y[i] = 0.0; }}
#     151     }};
#     152
#     153     let problem = OdeBuilder::<M>::new()
#     154         .rhs_implicit(rhs, jac)
#     155         .init(init, {components["n_species"]})
#     156         .build()
#     157         .unwrap();
#     158
#     159     let mut solver = problem.bdf::<LS>().unwrap();
#     160     let mut time = Vec::new();
#     161
#     162     // Initialize result vectors
#     163 {components["result_vectors_init"]}
#     164
#     165     // First Dose
#     166     if !doses.is_empty() {{
#     167         let gut_idx = {components["gut_idx"]};
#     168         solver.state_mut().y[gut_idx] = doses[0].1;
#     169     }}
#     170
#     171 {components["initial_pushes"]}
#     172     time.push(0.0);
#     173
#     174     // Simulation Loop
#     175     for (t, dose) in doses.into_iter().skip(1) {{
#     176         solver.set_stop_time(t).unwrap();
#     177         loop {{
#     178             match solver.step() {{
#     179                 Ok(OdeSolverStopReason::InternalTimestep) => {{
#     180 {components["loop_pushes"]}
#     181                     time.push(solver.state().t);
#     182                 }},
#     183                 Ok(OdeSolverStopReason::TstopReached) => break,
#     184                 Ok(OdeSolverStopReason::RootFound(_)) => break,
#     185                 Err(_) => panic!("Solver Error"),
#     186             }}
#     187         }}
#     188         let gut_idx = {components["gut_idx"]};
#     189         solver.state_mut().y[gut_idx] += dose;
#     190     }}
#     191
#     192     let final_time = sim_params.final_time.unwrap_or(24.0);
#     193     solver.set_stop_time(final_time).unwrap();
#     194     loop {{
#     195         match solver.step() {{
#     196             Ok(OdeSolverStopReason::InternalTimestep) => {{
#     197 {components["loop_pushes"]}
#     198                 time.push(solver.state().t);
#     199             }},
#     200             Ok(OdeSolverStopReason::TstopReached) => break,
#     201             Ok(OdeSolverStopReason::RootFound(_)) => break,
#     202             Err(_) => panic!("Solver Error"),
#     203         }}
#     204     }}
#     205
#     206     let mut species_map = HashMap::new();
#     207 {components["map_inserts"]}
#     208
#     209     let result = SimulationResult {{
#     210         time,
#     211         species: species_map,
#     212     }};
#     213
#     214     serde_json::to_string(&result).unwrap()
#     215 }}
#     216 '''
#     217         return template
#
# KeyError: 'species_fields'
