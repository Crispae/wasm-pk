# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load the simulation results
with open('euromix.json', 'r') as f:
    data = json.load(f)

# Extract data
time = np.array(data['time'])
species = data['species']

print("Available species in euromix model:")
print(list(species.keys()))
print(f"\nTime points: {len(time)}")
print(f"Time range: {time[0]:.4f} to {time[-1]:.4f} hours")
